# %%
import pandas as pd
import seaborn as sns

# %%
avocados = pd.read_csv('avocado.csv', index_col=0, )
avocados['Date'] = pd.to_datetime(avocados['Date'])
avocados.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
sns.set_style('white')
guac = avocados['type']=='conventional'

# %%
g = sns.factorplot('AveragePrice','region',data=avocados[guac], hue='year', size=8, aspect=0.6, join=False )

# %%
regions = ['PhoenixTucson', 'Chicago']
guac = (avocados['region'].isin(regions)& (avocados['type']=='conventional'))

# %%
avocados['Month'] = avocados['Date'].dt.month
avocados[guac].head()
# Out:
#         Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0 2015-12-27          0.93     661137.13  42799.00  445218.79  78378.25
# 1 2015-12-20          0.91     690669.34  35724.99  464574.15  96306.30
# 2 2015-12-13          1.07     668601.50  40380.09  451470.42  94162.53
# 3 2015-12-06          1.14     664020.49  53173.18  455048.11  92888.37
# 4 2015-11-29          1.11     602481.22  42851.47  422479.32  74988.97
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0    94741.09    83066.75     1617.67     10056.67  conventional  2015
# 1    94063.90    76241.25     9592.65      8230.00  conventional  2015
# 2    82588.46    76829.42     5693.75        65.29  conventional  2015
# 3    62910.83    62473.12      420.95        16.76  conventional  2015
# 4    62161.46    61862.57      298.89         0.00  conventional  2015
#
#     region  Month
# 0  Chicago     12
# 1  Chicago     12
# 2  Chicago     12
# 3  Chicago     12
# ...

# %%
order = ( avocados[guac & (avocados['year']==2018)].groupby('region')['AveragePrice'].mean().sort_values().index)

# %%
g = sns.factorplot('AveragePrice','region',data=avocados[guac], hue='year', size=8, aspect=0.6, join=False )
g
